# %%
def sumOfTwoArrays(arr1, n, arr2, m, ou) :
    # a = 0
    # b = 0 
    # for i in range (n):
    #     a = a*10 + arr1[i]
    # j = 0 
    # while j < m :
    #     b = b*10 + arr2[j]
    #     j+=1
    # sum = a+b
    # sum = [int(i) for i in str(sum)]
    # for i in range(len(sum)):
    #     output[len(output)-1-i] = sum[len(sum)-1-i]
    # for i in  output:
    #     print(i, end = ' ')
    i = n-1
    j = m-1
    k = len(ou)-1
    carry = 0
    while i > -1 and j > -1 and k > -1 :
        num = arr1[i]+arr2[j]+carry
        rev = num % 10 
        carry = num//10
        ou[k] = rev 
        i-=1
        j-=1
        k-=1
    while i > -1 and k > -1 :
        num = arr1[i] + carry
        rev = num%10
        carry = num//10
        ou[k] = rev
        i-=1
        k-=1
    while j>-1 and k > -1 :
        num = arr2[j] + carry
        rev = num%10
        carry = num//10
        ou[k] = rev
        i-=1
        k-=1
    if carry!=0 :
    	ou[k]=carry
    for i in ou :
        print(i,end = ' ')
    


#main
t = int(input())

while t > 0 :
    n = int ( input())
    if n == 0 :
        arr1 = []
    else :
        arr1 = [int(i) for i in input().split()]
    m = int(input())
    if m == 0 :
        arr2 = []
    else :
        arr2 = [int(i) for i in input().split()]
    outputSize = (1 + max(n, m))
    output = outputSize * [0]
    
    sumOfTwoArrays(arr1, n, arr2, m, output)
    t -= 1
